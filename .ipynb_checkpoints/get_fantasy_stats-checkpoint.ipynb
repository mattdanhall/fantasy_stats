# %%
import fantasy_stats_def as fs
import pandas as pd

# %% [markdown]
# #### Get all info (only run when new info to retrieve) ####

# %%
all_lineups_df = fs.get_all_lineups()

# %%
league_stats_df_by_gameweek = fs.get_league_stats_df_by_gameweek(all_lineups_df)
league_stats_df_by_gameweek_with_bench = fs.get_league_stats_df_by_gameweek(all_lineups_df, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9a4673a08ba4> in <module>
# ----> 1 league_stats_df_by_gameweek = fs.get_league_stats_df_by_gameweek(all_lineups_df)
#       2 league_stats_df_by_gameweek_with_bench = fs.get_league_stats_df_by_gameweek(all_lineups_df, True)
#
# NameError: name 'all_lineups_df' is not defined

# %%
league_points_df = fs.get_league_points_df(cumulative = True, totals = False)
league_positions_df = fs.get_league_positions_df()
league_standings_df = pd.concat([league_points_df, league_positions_df],keys=['points','position']).swaplevel(0,1).groupby(level=[0,1]).sum()

# %% [markdown]
# #### Play with info ####

# %%
league_standings_df
# Out:
#                   1    2
# Emma   points    43  105
#        position   2    1
# Claire points    39   85
#        position   3    2
# Luke   points    27   84
#        position   5    3
# Olivia points    31   82
#        position   4    4
# Matt   points    22   78
#        position   7    5
# Fat    points    48   73
#        position   1    6
# George points    26   64
#        position   6    7

# %%
all_lineups_df['Emma',2]
# Out:
#                             name       team    position  value selected %  \
# 252                      Alisson  Liverpool  Goalkeeper      6    10.9485
# 62                          Dunk   Brighton    Defender      5    7.59016
# 458                         Boly     Wolves    Defender    5.5    2.28867
# 323                    Fernández  Newcastle    Defender      5     1.5353
# 254                        Salah  Liverpool  Midfielder     12    35.5182
# 241                       Milner  Liverpool  Midfielder    5.5   0.192532
# 113                        Kanté    Chelsea  Midfielder      5    4.32095
# 193                    Hernández      Leeds  Midfielder      6    1.67499
# 388                         Kane      Spurs     Forward   10.5    12.3814
# 268                       Agüero   Man City     Forward   10.5    3.51415
# 166                  Richarlison    Everton     Forward      8    10.8746
# 56                        Button  West Brom  Goalkeeper      4    4.84438
# 154                      Bernard    Everton  Midfielder      6   0.166727
# 102                  Azpilicueta    Chelsea    Defender      6    6.07621
# 81                     Tarkowski    Burnley    Defender    5.5    5.19155
# totals (inc. bench)            9         11              100.5    7.14122
# totals                         9          9                 79    8.25814
#
#                     minutes goals scored goals conceded penalties missed  \
# 252                      90            0              0                0
# 62                       90            0              0                0
# 458                      90            0              3                0
# 323                      90            0              3                0
# 254                      90            0              0                0
# 241                      26            0              0                0
# 113                      90            0              2                0
# 193                       0            0              0                0
# 388                      83            1              1                0
# 268                       0            0              0                0
# 166                      90            0              2                0
# 56                        0            0              0                0
# 154                       0            0              0                0
# 102                       0            0              0                0
# 81                        0            0              0                0
# totals (inc. bench)     739            1             11                0
# totals                  739            1             11                0
#
#                     penalties saved assists saves own goals yellow cards  \
# 252                               1       0     3         0            0
# 62                                0       0     0         0            0
# 458                               0       0     0         0            0
# 323                               0       0     0         0            0
# 254                               0       0     0         0            0
# 241                               0       0     0         0            0
# 113                               0       0     0         0            0
# 193                               0       0     0         0            0
# 388                               0       4     0         0            0
# 268                               0       0     0         0            0
# 166                               0       3     0         0            0
# 56                                0       0     0         0            0
# 154                               0       0     0         0            0
# 102                               0       0     0         0            0
# 81                                0       0     0         0            0
# totals (inc. bench)               1       7     3         0            0
# totals                            1       7     3         0            0
#
#                     red cards foul points total points
# 252                         0           0           14
# 62                          0           0            7
# 458                         0           0            1
# 323                         0           0            1
# 254                         0           0            3
# 241                         0           0            1
# 113                         0           0            2
# 193                         0           0            0
# 388                         0           0           21
# 268                         0           0            0
# 166                         0           0           12
# 56                          0           0            0
# 154                         0           0            0
# 102                         0           0            0
# 81                          0           0            0
# totals (inc. bench)         0           0           62
# totals                      0           0           62

# %%
league_stats_df_by_gameweek[1]
# Out:
#        active players team value selected % minutes  productivity  \
# Fat                11    8  70.5    7.29949     913      0.052574
# Emma               10    9    69    7.67975     786      0.054707
# Claire             10    9    76    5.40426     799      0.048811
# Olivia             11    8    73    7.83985     953      0.032529
# Luke                9    8    75    14.6122     610      0.044262
# George              9    9    59    5.53675     685      0.037956
# Matt                7    8  53.5    4.61482     509      0.043222
#
#        goals scored goals conceded goal difference penalties missed  \
# Fat               3             11              -8                0
# Emma              3             14             -11                0
# Claire            2             13             -11                0
# Olivia            2             13             -11                0
# Luke              0              7              -7                0
# George            0             10             -10                0
# Matt              2             12             -10                0
#
#        penalties saved assists saves own goals yellow cards red cards  \
# Fat                  0       1     3         0            0         0
# Emma                 0       0     0         0            0         0
# Claire               0       3     0         0            2         0
# Olivia               0       1     2         0            2         0
# Luke                 0       1     1         0            0         0
# George               0       0     5         0            1         0
# Matt                 0       1     0         0            0         0
#
#        foul points total points weekly position
# Fat              0           48               1
# Emma             0           43               2
# Claire           2           39               3
# Olivia           2           31               4
# Luke             0           27               5
# George           1           26               6
# Matt             0           22               7

# %%
league_stats_df_by_gameweek[2][['goals scored','goals conceded','goal difference','weekly position']].sort_values('goal difference', ascending=False)
# Out:
#        goals scored goals conceded goal difference weekly position
# George            4             12              -8               6
# Emma              1             11             -10               1
# Claire            5             19             -14               5
# Luke              4             19             -15               2
# Matt              5             20             -15               3
# Olivia            4             20             -16               4
# Fat               1             20             -19               7

# %%
df = fs.get_league_stats_df_by_stat(league_stats_df_by_gameweek_with_bench, 'goal difference', 'total')
pd.concat([df,league_stats_df_by_gameweek_with_bench[fs.current_gameweek][['weekly position']]],axis=1)
# Out:
#          1   2 totals weekly position
# George -10  -8    -18               6
# Emma   -11 -10    -21               3
# Luke    -7 -21    -28               2
# Olivia -11 -19    -30               5
# Claire -11 -19    -30               1
# Matt   -10 -20    -30               4
# Fat    -12 -24    -36               7
