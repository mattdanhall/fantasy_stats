# %%
import fantasy_stats_def as fs
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Get lineup info (only run when new info to retrieve) ####

# %%
all_lineups_df = fs.get_all_lineups()
league_stats_df_by_gameweek = fs.get_league_stats_df_by_gameweek(all_lineups_df)
league_stats_df_by_gameweek_with_bench = fs.get_league_stats_df_by_gameweek(all_lineups_df, True)

# %% [markdown]
# #### Get league info ####

# %%
league_points_df = fs.get_league_points_df(cumulative = True, totals = False)
league_positions_df = fs.get_league_positions_df()
league_standings_df = pd.concat([league_points_df, league_positions_df],keys=['points','position']).swaplevel(0,1).groupby(level=[0,1]).sum()
league_points_gap_df = fs.get_league_points_gap_df()

# %% [markdown]
# #### Play with info ####

# %%
league_points_df
# Out:
#          1    2    3    4    5    6    7    8
# Fat     48   73  123  194  224  259  317  357
# Luke    27   84  128  163  210  239  296  344
# Claire  39   85  115  177  218  264  293  342
# Matt    22   78  144  167  204  244  301  337
# Emma    43  105  132  180  213  238  271  313
# Olivia  31   82  123  141  181  218  262  312
# George  26   64   90  146  204  228  253  269

# %%
league_points_gap_df.transpose().plot()
# Out:
# <AxesSubplot:>

# %%
all_lineups_df['Matt',5]
# Out:
#                           name            team    position value selected %  \
# 325                     Darlow       Newcastle  Goalkeeper     5    1.60118
# 255                  Robertson       Liverpool    Defender     7    15.0791
# 146                   Mitchell  Crystal Palace    Defender   4.1    25.8167
# 123                      James         Chelsea    Defender   5.1    12.8584
# 41                       Mings     Aston Villa    Defender   5.1    5.70591
# 198                      Klich           Leeds  Midfielder   5.6    7.40763
# 231                   Maddison       Leicester  Midfielder     7    2.43942
# 284                      Foden        Man City  Midfielder   6.6    6.99956
# 137                   Townsend  Crystal Palace  Midfielder   6.1    3.61002
# 91                        Wood         Burnley     Forward   6.4    1.59504
# 437                    Antonio        West Ham     Forward   6.3    4.89761
# 96                        Pope         Burnley  Goalkeeper   5.5    12.0627
# 272                  De Bruyne        Man City  Midfielder  11.6    24.1281
# 224                      Vardy       Leicester     Forward  10.1     23.481
# 110                      Zouma         Chelsea    Defender     5    4.20275
# totals (inc. bench)         13              10              96.5    10.1257
# totals                      11              10              64.3    8.00096
#
#                     minutes goals scored goals conceded penalties missed  \
# 325                      90            0              4                0
# 255                      90            0              2                0
# 146                      90            0              1                0
# 123                       3            0              1                0
# 41                       90            0              0                0
# 198                      90            0              1                0
# 231                      22            0              1                0
# 284                      88            0              0                0
# 137                      90            0              1                0
# 91                       90            0              0                0
# 437                      76            0              3                0
# 96                       90            0              0                0
# 272                       0            0              0                0
# 224                       0            0              0                0
# 110                      90            0              3                0
# totals (inc. bench)     999            0             17                0
# totals                  819            0             14                0
#
#                     penalties saved assists saves own goals yellow cards  \
# 325                               1       0     8         0            0
# 255                               0       1     0         0            0
# 146                               0       0     0         0            1
# 123                               0       0     0         0            0
# 41                                0       0     0         0            0
# 198                               0       0     0         0            0
# 231                               0       0     0         0            0
# 284                               0       1     0         0            0
# 137                               0       0     0         0            0
# 91                                0       0     0         0            0
# 437                               0       0     0         0            1
# 96                                0       0     6         0            0
# 272                               0       0     0         0            0
# 224                               0       0     0         0            0
# 110                               0       0     0         0            0
# totals (inc. bench)               1       2    14         0            2
# totals                            1       2     8         0            2
#
#                     red cards foul points total points
# 325                         0           0            8
# 255                         0           0            6
# 146                         0           1            1
# 123                         0           0            1
# 41                          0           0            7
# 198                         0           0            2
# 231                         0           0            1
# 284                         0           0            6
# 137                         0           0            2
# 91                          0           0            2
# 437                         0           1            1
# 96                          0           0           11
# 272                         0           0            0
# 224                         0           0            0
# 110                         0           0            1
# totals (inc. bench)         0           2           49
# totals                      0           2           37

# %%
league_stats_df_by_gameweek[8]
# Out:
#        active players team value selected % minutes  productivity  \
# Olivia             11    9  76.9     8.5005     906      0.055188
# Claire             10    8  74.8    9.68298     844      0.058057
# Luke               11    9  72.4    14.3447     916      0.052402
# Emma                9    8  79.2    10.3408     747      0.056225
# Fat                11    7  67.1    11.9379     977      0.040942
# Matt               11   10  71.3    9.97414     970      0.037113
# George              9    8  70.2    9.12367     652      0.024540
#
#        goals scored goals conceded goal difference penalties missed  \
# Olivia            2              9              -7                0
# Claire            1             13             -12                0
# Luke              4             14             -10                0
# Emma              3              9              -6                0
# Fat               1              9              -8                0
# Matt              2             11              -9                2
# George            0              8              -8                0
#
#        penalties saved assists saves own goals yellow cards red cards  \
# Olivia               0       1     2         1            0         0
# Claire               1       3     3         0            1         0
# Luke                 0       1     2         0            3         0
# Emma                 0       1     1         0            1         0
# Fat                  0       1     2         0            0         0
# Matt                 0       2     5         0            2         0
# George               0       0     2         0            3         0
#
#        foul points total points weekly position
# Olivia           0           50               1
# Claire           1           49               2
# Luke             3           48               3
# Emma             1           42               4
# Fat              0           40               5
# Matt             2           36               6
# George           3           16               7

# %%
league_stats_df_by_gameweek[4][['goals scored','goals conceded','goal difference','weekly position']].sort_values('goal difference', ascending=False)
# Out:
#        goals scored goals conceded goal difference weekly position
# Emma              4             17             -13               4
# George            3             17             -14               3
# Claire            3             20             -17               2
# Luke              3             21             -18               5
# Fat               6             25             -19               1
# Olivia            0             20             -20               7
# Matt              1             25             -24               6

# %%
df = fs.get_league_stats_df_by_stat(league_stats_df_by_gameweek_with_bench, 'productivity', 'mean')
pd.concat([df,league_points_df[[fs.current_gameweek]].rename(columns={fs.current_gameweek: 'total points'})],axis=1).sort_values('total points', ascending=False)
# Out:
#                 1          2          3          4          5          6  \
# Fat     0.0471785   0.028757  0.0531814  0.0687679  0.0354553  0.0341506
# Luke    0.0485714   0.053913  0.0439771  0.0442638  0.0526316  0.0485762
# Claire  0.0506187  0.0601504  0.0391304   0.064333  0.0462487  0.0619883
# Matt     0.043222  0.0523466  0.0586345   0.019948   0.049049  0.0519366
# Emma    0.0547074  0.0838972  0.0348387  0.0633245  0.0439189  0.0326087
# Olivia  0.0325289  0.0513069  0.0369686  0.0197926  0.0501701  0.0367412
# George  0.0379562  0.0551524   0.037196  0.0698254  0.0717822  0.0342368
#
#                 7          8   average total points
# Fat     0.0634573  0.0336808  0.045579          357
# Luke    0.0575264  0.0536779  0.050392          344
# Claire  0.0327869  0.0611222  0.052047          342
# Matt    0.0620301  0.0424528  0.047452          337
# Emma    0.0454545  0.0562249  0.051872          313
# Olivia  0.0466613  0.0459184  0.040011          312
# George  0.0344353  0.0245399  0.045641          269

# %%
df = fs.get_league_stats_df_by_stat(league_stats_df_by_gameweek_with_bench, 'penalties missed', 'total')
# df = pd.concat([df,league_points_df[[fs.current_gameweek]].rename(columns={fs.current_gameweek: 'total points'})],axis=1)
df.sort_values(df.columns[-1], ascending=False)
# Out:
#         1  2  3  4  5  6  7  8 totals
# Luke    0  0  0  0  2  0  0  0      2
# Matt    0  0  0  0  0  0  0  2      2
# Fat     0  1  0  0  0  0  0  0      1
# Emma    0  0  0  0  0  0  0  0      0
# Olivia  0  0  0  0  0  0  0  0      0
# Claire  0  0  0  0  0  0  0  0      0
# George  0  0  0  0  0  0  0  0      0
